# %%
# round(np.min(p_wage),2)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
visa_df=pd.read_csv("Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.describe()
p_wage=visa_df['prevailing_wage']

mini=round(p_wage.min(),2)
maxx=round(p_wage.max(),2)
count=round(p_wage.count())
mean=round(p_wage.mean(),2)
median=round(p_wage.median(),2)
std=round(p_wage.std(),2)
mini,maxx,count,mean,median,std

p_25=round(np.percentile(p_wage,25),2)
p_50=round(np.percentile(p_wage,50),2)
p_75=round(np.percentile(p_wage,75),2)

# %%
visa_df.describe()
p_wage=visa_df['prevailing_wage']

mini=round(p_wage.min(),2)
maxx=round(p_wage.max(),2)
count=round(p_wage.count())
mean=round(p_wage.mean(),2)
median=round(p_wage.median(),2)
std=round(p_wage.std(),2)
mini,maxx,count,mean,median,std

p_25=round(np.percentile(p_wage,25),2)
p_50=round(np.percentile(p_wage,50),2)
p_75=round(np.percentile(p_wage,75),2)

# %%
# p_wage=visa_df['prevailing_wage']
# ########## PANDAS  ##############
# count = round(p_wage.count(),2)
# minn = round(p_wage.min(),2)
# maxx= round(p_wage.max(),2)
# mean = round(p_wage.mean(),2)
# median = round(p_wage.median(),2)
# std=round(p_wage.std(),2)

# ######  NUMPY ####################
# p_25=round(np.percentile(p_wage,25),2)
# p_50=round(np.percentile(p_wage,50),2)
# p_75=round(np.percentile(p_wage,75),2)



# list1=[wage_count ,
# minn,
# maxx ,
# mean ,
# median,
# std,
# p_25,
# p_50,
# p_75 ]

# index_list=['Count','Min','Max','Mean','Median','std','25p','50p','75p']
# table=pd.DataFrame(list1,columns=['prevailing_wage'],
#             index=index_list)
# table

# %%
visa_df['prevailing_wage']
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
round(np.max(p_wage),2)
# Out:
# 319210.27

# %%
round(np.std(p_wage),2)
# Out:
# 52814.91

# %% [markdown]
# **Percentale and quantile**
# - in the numpy package we have the np.percentile() and np.quartile()
#
# - percentile: if you want to 25p  25
#
# - quantile: q1=25p (0.25)  q2=50p   q3=75p
#
# - assume that a student got 120 marks 95p
#
# - 95% of students has marks below 120

# %%
p_wage=visa_df['prevailing_wage']
########## PANDAS  ##############
wage_count = round(p_wage.count(),2)
wage_min = round(p_wage.min(),2)
wage_max = round(p_wage.max(),2)
wage_mean = round(p_wage.mean(),2)
wage_median = round(p_wage.median(),2)
wage_std=round(p_wage.std(),2)

######  NUMPY ####################
wage_25p=round(np.percentile(p_wage,25),2)
wage_50p=round(np.percentile(p_wage,50),2)
wage_75p=round(np.percentile(p_wage,75),2)



list1=[wage_count ,
wage_min,
wage_max ,
wage_mean ,
wage_median,
wage_std,
wage_25p,
wage_50p,
wage_75p ]

index_list=['Count','Min','Max','Mean','Median','std','25p','50p','75p']
table=pd.DataFrame(list1,columns=['prevailing_wage'],
            index=index_list)
table
# Out:
#         prevailing_wage
# Count          25480.00
# Min                2.14
# Max           319210.27
# Mean           74455.81
# Median         70308.21
# std            52815.94
# 25p            34015.48
# 50p            70308.21
# 75p           107735.51

# %%
num_cols=visa_df.select_dtypes(exclude='object').columns
dict1={}
for i in num_cols:
    
    count = round(visa_df[i].count(),2)
    minn = round(visa_df[i].min(),2)
    maxx = round(visa_df[i].max(),2)
    mean = round(visa_df[i].mean(),2)
    median = round(visa_df[i].median(),2)
    std=round(visa_df[i].std(),2)

    _25p=round(np.percentile(visa_df[i],25),2)
    _50p=round(np.percentile(visa_df[i],50),2)
    _75p=round(np.percentile(visa_df[i],75),2)

    list1=[count ,minn,maxx ,mean ,medianstd,_25p,_50p,_75p ]
    dict1[i]=list1

index_list=['Count','Min','Max','Mean','Median','std','_25p','_50p','_75p']
numeric_df = pd.DataFrame(dict1,index=index_list)
numeric_df.to_csv('number_df.csv')
numeric_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 16
#      13     _50p=round(np.percentile(visa_df[i],50),2)
#      14     _75p=round(np.percentile(visa_df[i],75),2)
# ---> 16     list1=[count ,minn,maxx ,mean ,medianstd,_25p,_50p,_75p ]
#      17     dict1[i]=list1
#      19 index_list=['Count','Min','Max','Mean','Median','std','_25p','_50p','_75p']
#
# NameError: name 'medianstd' is not defined

# %%
25*(25480)/100,50*(25480)/100,75*(25480)/100
# Out:
# (6370.0, 12740.0, 19110.0)

# %%
p_wage[p_wage<34015]
# Out:
# 0          592.2029
# 7          418.2298
# 12       28663.0500
# 16        3706.7900
# 17       16132.6100
#             ...
# 25461       54.9196
# 25465      481.2238
# 25466     6973.4000
# 25470      516.4101
# 25473    22845.5600
# Name: prevailing_wage, Length: 6370, dtype: float64

# %%
count_25p=len(p_wage[p_wage<np.percentile(p_wage,25)])
count_50p=len(p_wage[p_wage<np.percentile(p_wage,50)])
count_75p=len(p_wage[p_wage<np.percentile(p_wage,75)])



l1=['Count of 25%','Count of 50%','Count of 75%']
l2=[count_25p,count_50p,count_75p]
d1=pd.DataFrame(zip(l1,l2),columns=['Till per','count'])
plt.bar('Till per','count',data=d1)
plt.title('BAR chart ')
plt.xlabel('count')
plt.ylabel('members')
plt.show()

# %%
# youn want to extract a dataframe 
# whicha has the wages less than 25p
# 100 25mem 34k

# %%
# step1: take the reference column first

# step2: apply the condition
#         it will provide 2 or false
# step3:  apply the original data frame on top of that so that it shall give only true values

visa_df[visa_df['prevailing_wage']<34015]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
p_wage=visa_df['prevailing_wage']
p_25=np.percentile(p_wage,25)
con=p_wage<p_25
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
p_wage=visa_df['prevailing_wage']
p_50=np.percentile(p_wage,50)
con=p_wage<p_50
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 6         EZYV07           Asia            Bachelor's                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 9         EZYV10         Europe             Doctorate                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# ...          ...            ...                   ...                ...
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
p_wage=visa_df['prevailing_wage']

p_25=np.percentile(p_wage,25)
p_50=np.percentile(p_wage,50)
p_25,p_50
con1=p_wage>p_25 
con2=p_wage<p_50

visa_df[con1]
visa_df[con2]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
p_wage=visa_df['prevailing_wage']

p_25=np.percentile(p_wage,25)
p_50=np.percentile(p_wage,50)
p_75=np.percentile(p_wage,75)

con1=p_wage>p_50 
con2=p_wage<p_75

visa_df[p_wage>p_25]
visa_df[p_wage<p_75]

visa_df[con1 & con2]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# 8         EZYV09      Asia            Bachelor's                  N
# 10        EZYV11      Asia              Master's                  N
# ...          ...       ...                   ...                ...
# 25471  EZYV25472      Asia           High School                  N
# 25472  EZYV25473      Asia           High School                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# - from raw data will make the clthe observations in each claass intervels
#
# - will count the observations in ecah class intervels
#
# - freq distribution table
#
# - plot of freq distribution table is histogram

# %%
p_wage=visa_df['prevailing_wage']
frequency,intervel,count=plt.hist(p_wage,bins=50)
frequency,intervel,count
# Out:
# (array([2813.,  708.,  725.,  832.,  960.,  993., 1109., 1132., 1108.,
#         1162., 1184., 1154., 1159., 1117., 1067., 1047.,  953.,  955.,
#          816.,  780.,  673.,  539.,  469.,  364.,  289.,  211.,  139.,
#          107.,   81.,   86.,   79.,   87.,   78.,   69.,   60.,   49.,
#           57.,   52.,   45.,   37.,   28.,   27.,   26.,   20.,   13.,
#            4.,    5.,    4.,    4.,    4.]),
#  array([2.13670000e+00, 6.38629937e+03, 1.27704620e+04, 1.91546247e+04,
#         2.55387874e+04, 3.19229500e+04, 3.83071127e+04, 4.46912754e+04,
#         5.10754380e+04, 5.74596007e+04, 6.38437634e+04, 7.02279260e+04,
#         7.66120887e+04, 8.29962514e+04, 8.93804140e+04, 9.57645767e+04,
#         1.02148739e+05, 1.08532902e+05, 1.14917065e+05, 1.21301227e+05,
#         1.27685390e+05, 1.34069553e+05, 1.40453715e+05, 1.46837878e+05,
#         1.53222041e+05, 1.59606203e+05, 1.65990366e+05, 1.72374529e+05,
# ...

# %%
# 2.13670000e+00, 6.38629937e+03
p_wage=visa_df['prevailing_wage']


condition1 = 2.13670000e+00 >p_wage
condition2 = p_wage<6.38629937e+03

pd.DataFrame(visa_df[condition1 & condition2])
# Out:
# Empty DataFrame
# Columns: [case_id, continent, education_of_employee, has_job_experience, requires_job_training, no_of_employees, yr_of_estab, region_of_employment, prevailing_wage, unit_of_wage, full_time_position, case_status]
# Index: []

# %%
p_wage=visa_df['prevailing_wage']
frequency,intervel,count=plt.hist(p_wage,bins=50)
# frequency,

type(intervel)
# Out:
# numpy.ndarray

# %%
intervel=list(intervel)
frequency=list(frequency)
# type(frequency)
# intervel
class_intervel=[]
for index,item in enumerate(intervel):
    if index!=len(intervel)-1:
        class_intervel.append([str(item)+' - '+str(intervel[index+1]),frequency[index]])
class_intervel
col=['Class Intervel','Frequency']
table=pd.DataFrame(class_intervel,columns=col)
table
# Out:
#                              Class Intervel  Frequency
# 0                2.1367 - 6386.299366000001     2813.0
# 1    6386.299366000001 - 12770.462032000001      708.0
# 2   12770.462032000001 - 19154.624698000003      725.0
# 3   19154.624698000003 - 25538.787364000003      832.0
# 4   25538.787364000003 - 31922.950030000004      960.0
# 5    31922.950030000004 - 38307.11269600001      993.0
# 6     38307.11269600001 - 44691.27536200001     1109.0
# 7     44691.27536200001 - 51075.43802800001     1132.0
# 8    51075.43802800001 - 57459.600694000015     1108.0
# 9    57459.600694000015 - 63843.76336000001     1162.0
# 10    63843.76336000001 - 70227.92602600002     1184.0
# 11    70227.92602600002 - 76612.08869200002     1154.0
# 12    76612.08869200002 - 82996.25135800002     1159.0
# 13    82996.25135800002 - 89380.41402400001     1117.0
# 14    89380.41402400001 - 95764.57669000002     1067.0
# 15   95764.57669000002 - 102148.73935600002     1047.0
# ...

# %%
# table 
# intervel                       count

# %%
# inter_vel=[]
# for i in intervel:
#     inter_vel=[intervel[]]

# %%
sns.displot(visa_df['prevailing_wage'],kind='ecdf')
# ecdf= cummulative distripution plot
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(visa_df['prevailing_wage']) #Histogram

sns.displot(visa_df['prevailing_wage'],kind='kde')   #kernal density estimation

sns.displot(visa_df['prevailing_wage'],kind='ecdf')  #cummulative distribition plot
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.subplot(1,3,1)  #1,2 1row 2 columns
sns.displot(visa_df['prevailing_wage']).subplot(1,3,3)
plt.subplot(1,3,2)
sns.displot(visa_df['prevailing_wage'],kind='kde').subplot(1,3,3)
plt.subplot(1,3,3)
sns.displot(visa_df['prevailing_wage'],kind='ecdf').subplot(1,3,3)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 2
#       1 plt.subplot(1,3,1)  #1,2 1row 2 columns
# ----> 2 sns.displot(visa_df['prevailing_wage']).subplot(1,3,3)
#       3 plt.subplot(1,3,2)
#       4 sns.displot(visa_df['prevailing_wage'],kind='kde').subplot(1,3,3)
#
# AttributeError: 'FacetGrid' object has no attribute 'subplot'

# %%
plt.subplot(1,3,1)
plt.subplot(1,3,2)
plt.subplot(1,3,3)

# %%
plt.subplot(1,3,1)  #1,2 1row 2 columns
plt.hist(visa_df['prevailing_wage'])
plt.subplot(1,3,2)
plt.hist(visa_df['prevailing_wage'])
plt.subplot(1,3,3)
plt.hist(visa_df['prevailing_wage'])
