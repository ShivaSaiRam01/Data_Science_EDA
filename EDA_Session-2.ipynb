# %% [markdown]
# edited with git

# %%
print("git hub")
# Out:
# git hub

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **read the data**

# %%
# import os
file_name='C:\\Users\\merug\\OneDrive\\Naresh_it\\Data_Science\\Data_files\\Visadataset.csv'
with open(file_name) as file:
    visa_df=pd.read_csv(file)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
file_name='C:\\Users\\merug\\OneDrive\\Naresh_it\\Data_Science\\Data_files\\Visadataset.csv'
visa_df=pd.read_csv(file_name)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#your name of the data frame : visa _df
#<packagename>  #it will return top 5
visa_df.head(5)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_df.tail(6)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25474                     N             2594         1979
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
# ...

# %%
# dir(visa_df)

# %% [markdown]
# $shape$

# %%
visa_df.shape
#shape : m,n (rows,coloums)
#nuber of rows are 25480
#numebr of colums are 12
# Out:
# (25480, 12)

# %%
type(visa_df.shape)
# Out:
# tuple

# %%
visa_df.shape[0],visa_df.shape[1]
# Out:
# (25480, 12)

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
dir(visa_df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
# ...

# %% [markdown]
# $size$

# %%
visa_df.shape[0]*visa_df.shape[1]
# Out:
# 305760

# %%
visa_df.size
# Out:
# 305760

# %%
len(visa_df)
# Out:
# 25480

# %% [markdown]
# $columns$

# %%
visa_df.columns
#it will provide all 12 columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(visa_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
cols=visa_df.columns
cols.to_list()
cols_list=cols.to_list()
type(cols_list)
# Out:
# list

# %% [markdown]
# $dtypes$

# %%
visa_df.dtypes
#object: thevalues under that column are categorical
#int/float: the value under that columns are numerical

#seriestype
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# $info$

# %%
visa_df.info()
#caseid 25400
#out of 25480 rows 80 values are missed:Null
#Null count:80
#Non null Count:25400
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# $isnull$

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isna()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isna().sum()
# visa_df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# - read the csv file
# - head
# - tail
# - shape
# - size
# - len
# - columns
# - dtypes
# - info
# - isnull

# %%
# visa_df.columns()

# 'Index' object is not callable   -- tHEN ITS A FUNCTION ITS NOT CALLABLE

# %%
visa_df.head
#bound method or built-in function please provide the ()
# Out:
# <bound method NDFrame.head of          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# - not callable
#     - 'Index' object is not callable
#     - tHEN ITS A FUNCTION ITS NOT CALLABLE
#     - remove those brackets
# - bound method or built-in function
#     - please provide the ()

# %% [markdown]
# - Attribute Error:
#     - you provided a method which does not have
#     - please check the spelling
#     - or use the dir to check the method existed or not

# %%
visa_df.dtypes
# I want to seperate the categorical and numerical
#hint:convert into dict
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
dtype=dict(visa_df.dtypes)

# %%
for i in dtype:
    if dtype[i]=='object':
        print(i,dtype[i])
# Out:
# case_id object
# continent object
# education_of_employee object
# has_job_experience object
# requires_job_training object
# region_of_employment object
# unit_of_wage object
# full_time_position object
# case_status object

# %%
cat_col=[i for i in dtype if dtype[i]=='object']
num_col=[i for i in dtype if dtype[i]!='object']
cat_col,num_col
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
visa_df.select_dtypes(include='object')
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training region_of_employment unit_of_wage  \
# 0                         N                 West         Hour
# ...

# %%
visa_df.select_dtypes(include='object').columns #data frame
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
dtype=dict(visa_df.dtypes)
cat_col=[i for i in dtype if dtype[i]=='object']
num_col=[i for i in dtype if dtype[i]!='object']
cat_col,num_col

visa_df.select_dtypes(include='object').columns
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
# head : first five rows
# tail : last 5 rows
# if you want some specidic rows 
# if you want middle rows
# if you want specific columns data

# %% [markdown]
# $take  - loc -  iloc$

# %%
visa_df.take([1,2,3])
# by default axis = 0 ====> rows
# provide the rows which has index = 1,2,3 and all the columns
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 1         83425.65         Year                  Y   Certified
# 2        122996.86         Year                  Y      Denied
# 3         83434.03         Year                  Y      Denied

# %%
visa_df.take([i for i in range(10)])
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %%
visa_df.take([1,2,3],axis=1)
#The output is columns 
#index = 1,2,3
# Out:
#       continent education_of_employee has_job_experience
# 0          Asia           High School                  N
# 1          Asia              Master's                  Y
# 2          Asia            Bachelor's                  N
# 3          Asia            Bachelor's                  N
# 4        Africa              Master's                  Y
# ...         ...                   ...                ...
# 25475      Asia            Bachelor's                  Y
# 25476      Asia           High School                  Y
# 25477      Asia              Master's                  Y
# 25478      Asia              Master's                  Y
# 25479      Asia            Bachelor's                  Y
#
# [25480 rows x 3 columns]

# %%
visa_df.take([100,200,300]).take([2,3],axis=1)
# Out:
#     education_of_employee has_job_experience
# 100              Master's                  Y
# 200             Doctorate                  Y
# 300              Master's                  Y

# %%
visa_df.take([1,2,3])  #rows and all the columns
visa_df.take([1,2,3],axis=1)   # columnsa and all the rows
visa_df.take([100,200,300]).take([2,3],axis=1)  # rows and columns
# Out:
#     education_of_employee has_job_experience
# 100              Master's                  Y
# 200             Doctorate                  Y
# 300              Master's                  Y

# %%
visa_df.take([1,2,3],axis=1).take([2,3],axis=0)
# Out:
#   continent education_of_employee has_job_experience
# 2      Asia            Bachelor's                  N
# 3      Asia            Bachelor's                  N

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
dir(visa_df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
# ...

# %%
# read the data
# quick checks
# list
# string
# dict
# index

# %% [markdown]
# **iloc**

# %%
# when ever we open jupiter notebook
# please read the packages nad dataframe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_name='C:\\Users\\merug\\OneDrive\\Naresh_it\\Data_Science\\Data_files\\Visadataset.csv'
visa_df=pd.read_csv(file_name)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.iloc[<rows>,<columns>]
visa_df.iloc[<start:end>,<start:end>]
visa_df.iloc[[rows index ],[columns index]]

# %%
visa_df.iloc[3:6,:]
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
# 5  EZYV06      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
# 5                     N             2339         2012                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 3         83434.03         Year                  Y      Denied
# 4        149907.39         Year                  Y   Certified
# 5         78252.14         Year                  Y   Certified

# %%
visa_df.iloc[[6],[9]]
# Out:
#   unit_of_wage
# 6         Year

# %%
visa_df.iloc[54:58,0:3]  #54 to 58 index rws and 0to3 index columns
visa_df.iloc[5:10,]   #35 to 10 rows and all columns
visa_df.iloc[:,:2] #all the rows only 0 and 1s t column
# Out:
#          case_id continent
# 0         EZYV01      Asia
# 1         EZYV02      Asia
# 2         EZYV03      Asia
# 3         EZYV04      Asia
# 4         EZYV05    Africa
# ...          ...       ...
# 25475  EZYV25476      Asia
# 25476  EZYV25477      Asia
# 25477  EZYV25478      Asia
# 25478  EZYV25479      Asia
# 25479  EZYV25480      Asia
#
# [25480 rows x 2 columns]

# %%
rows=[100,200,300]
cols=[2,7]
visa_df.iloc[rows,cols]
# Out:
#     education_of_employee region_of_employment
# 100              Master's            Northeast
# 200             Doctorate                 West
# 300              Master's              Midwest

# %%
rows=[100,200,300]
cols=["education_of_employee","region_of_employment"]
visa_df.loc[rows,cols]
# Out:
#     education_of_employee region_of_employment
# 100              Master's            Northeast
# 200             Doctorate                 West
# 300              Master's              Midwest

# %% [markdown]
# iloc
# - iloc only takes the numerical entry, We cant provide the columns names directly
#
# - iloc takes only Column names only no index or numericals
